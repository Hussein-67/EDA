# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('/Users/hs.twin/Desktop/Analysis work1/foia-7afy2020-present-asof-231231.csv', encoding='latin1')
# Out:
# /var/folders/8d/g4smb9sx5vx16mf5_qp9yql00000gn/T/ipykernel_867/2072184223.py:1: DtypeWarning: Columns (34,35,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/hs.twin/Desktop/Analysis work1/foia-7afy2020-present-asof-231231.csv', encoding='latin1')

# %%
df.sample(5)
# Out:
#         AsOfDate Program                        BorrName         BorrStreet  \
# 30583   20231231      7A                   Blake G Koehn         612 SCR 68
# 107818  20231231      7A  Merschman Hardware and Buildin  650 E LeClaire Rd
# 68351   20231231      7A                        JJRS LLC   253 S NUTMEG WAY
# 88285   20231231      7A         Longitude 151 North LLC     2385 Parks Hwy
# 161756  20231231      7A                   Brust Co. LLC  3040 New York 23A
#
#           BorrCity BorrState  BorrZip  \
# 30583         Mize        MS    39116
# 107818    ELDRIDGE        IA    52748
# 68351     VINEYARD        UT    84059
# 88285     CANTWELL        AK    99729
# 161756  Palenville        NY    12463
#
#                                          BankName  BankFDICNumber  \
# 30583                                Peoples Bank          9366.0
# 107818                   First Central State Bank         19716.0
# 68351                                Central Bank          9204.0
# ...

# %%
df.shape
# Out:
# (213564, 40)

# %%
df.describe()
# Out:
#          AsOfDate        BorrZip  BankFDICNumber  BankNCUANumber  \
# count    213564.0  213564.000000   213564.000000     6296.000000
# mean   20231231.0   51565.868751    20309.783902    47660.918679
# std           0.0   29903.382693    17262.985613    22908.643602
# min    20231231.0     601.000000       58.000000       28.000000
# 25%    20231231.0   28804.000000     6560.000000    24692.000000
# 50%    20231231.0   48393.000000    18030.000000    62504.000000
# 75%    20231231.0   78754.000000    28489.000000    67390.000000
# max    20231231.0   99929.000000    91005.000000    97069.000000
#
#              BankZip  GrossApproval  SBAGuaranteedApproval  \
# count  213564.000000   2.135600e+05           2.135600e+05
# mean    45519.337290   5.551481e+05           4.235029e+05
# std     25314.741751   8.899933e+05           6.958625e+05
# min       613.000000   1.000000e+03           5.000000e+02
# 25%     28202.000000   5.500000e+04           3.740000e+04
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213564 entries, 0 to 213563
# Data columns (total 40 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   AsOfDate               213564 non-null  int64
#  1   Program                213564 non-null  object
#  2   BorrName               213562 non-null  object
#  3   BorrStreet             213564 non-null  object
#  4   BorrCity               213564 non-null  object
#  5   BorrState              213564 non-null  object
#  6   BorrZip                213564 non-null  int64
#  7   BankName               213564 non-null  object
#  8   BankFDICNumber         193199 non-null  float64
#  9   BankNCUANumber         6296 non-null    float64
#  10  BankStreet             213564 non-null  object
#  11  BankCity               213564 non-null  object
#  12  BankState              213564 non-null  object
#  13  BankZip                213564 non-null  int64
# ...

# %% [markdown]
# Data cleaning

# %%
df.duplicated().sum()
# Out:
# 895

# %% [markdown]
# The dupicate data is normal because we have many banks and a lot of locations

# %%
df.isna().sum()
# Out:
# AsOfDate              0
# Program               0
# BorrStreet            0
# BorrCity              0
# BorrState             0
# BorrZip               0
# BankName              0
# BankFDICNumber        0
# BankStreet            0
# BankCity              0
# BankState             0
# BankZip               0
# ApprovalDate          0
# ApprovalFiscalYear    0
# subpgmdesc            0
# TermInMonths          0
# ProjectState          0
# SBADistrictOffice     0
# LoanStatus            0
# RevolverStatus        0
# JobsSupported         0
# dtype: int64

# %% [markdown]
# As we can see we have a lot of missing values

# %%
sns.heatmap(df.isna())
# Out:
# <Axes: >

# %% [markdown]
# Dealing with missing values

# %%
from sklearn.impute import SimpleImputer

# %%
imp = SimpleImputer()

# %%
df['BankFDICNumber'] = imp.fit_transform(df[['BankFDICNumber']])

# %% [markdown]
# Droping unuseful culomns

# %%
df.drop('PaidInFullDate',axis=1,inplace=True )

# %%
df.dropna(axis=1, how='any', inplace=True)

# %%
df.isnull().sum()
# Out:
# AsOfDate              0
# Program               0
# BorrStreet            0
# BorrCity              0
# BorrState             0
# BorrZip               0
# BankName              0
# BankFDICNumber        0
# BankStreet            0
# BankCity              0
# BankState             0
# BankZip               0
# ApprovalDate          0
# ApprovalFiscalYear    0
# subpgmdesc            0
# TermInMonths          0
# ProjectState          0
# SBADistrictOffice     0
# LoanStatus            0
# RevolverStatus        0
# JobsSupported         0
# dtype: int64

# %%
df
# Out:
#         AsOfDate Program                      BorrStreet         BorrCity  \
# 0       20231231      7A     2919 S ELLSWORTH RD STE 124             MESA
# 1       20231231      7A                   2610 W 3rd St      Los Angeles
# 2       20231231      7A  3105 ALDERWOOD MALL BLVD Suite         LYNNWOOD
# 3       20231231      7A         2700 WASHINGTON BLVD #B        ARLINGTON
# 4       20231231      7A                 524 WOODSIDE RD     REDWOOD CITY
# ...          ...     ...                             ...              ...
# 213559  20231231      7A                 258 ATLANTIC ST    CENTRAL ISLIP
# 213560  20231231      7A                   3 TINKHAM AVE            DERRY
# 213561  20231231      7A                  701 NW 57th Pl  Fort Lauderdale
# 213562  20231231      7A          17674 EMMERSON AIRLINE           GIRARD
# 213563  20231231      7A               1309 CERVANTES CT           IRVINE
#
#        BorrState  BorrZip                                   BankName  \
# ...

# %%
df.isna().sum()
# Out:
# AsOfDate              0
# Program               0
# BorrStreet            0
# BorrCity              0
# BorrState             0
# BorrZip               0
# BankName              0
# BankFDICNumber        0
# BankStreet            0
# BankCity              0
# BankState             0
# BankZip               0
# ApprovalDate          0
# ApprovalFiscalYear    0
# subpgmdesc            0
# TermInMonths          0
# ProjectState          0
# SBADistrictOffice     0
# LoanStatus            0
# RevolverStatus        0
# JobsSupported         0
# dtype: int64

# %% [markdown]
# Handling outlires

# %%
df.plot(subplots=True,figsize=(20,10))
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >], dtype=object)

# %% [markdown]
# it sounds there's no outlires that can affects our data

# %% [markdown]
# time for analysis

# %%
df
# Out:
#                             AsOfDate Program                      BorrStreet  \
# 0      1970-01-01 00:00:00.020231231      7A     2919 S ELLSWORTH RD STE 124
# 1      1970-01-01 00:00:00.020231231      7A                   2610 W 3rd St
# 2      1970-01-01 00:00:00.020231231      7A  3105 ALDERWOOD MALL BLVD Suite
# 3      1970-01-01 00:00:00.020231231      7A         2700 WASHINGTON BLVD #B
# 4      1970-01-01 00:00:00.020231231      7A                 524 WOODSIDE RD
# ...                              ...     ...                             ...
# 213559 1970-01-01 00:00:00.020231231      7A                 258 ATLANTIC ST
# 213560 1970-01-01 00:00:00.020231231      7A                   3 TINKHAM AVE
# 213561 1970-01-01 00:00:00.020231231      7A                  701 NW 57th Pl
# 213562 1970-01-01 00:00:00.020231231      7A          17674 EMMERSON AIRLINE
# 213563 1970-01-01 00:00:00.020231231      7A               1309 CERVANTES CT
#
# ...

# %%
df['AsOfDate'] = pd.to_datetime(df['AsOfDate'])

# %%
df['BankName'].value_counts().head()
# Out:
# BankName
# The Huntington National Bank               22247
# U.S. Bank, National Association             9730
# TD Bank, National Association               9612
# Wells Fargo Bank, National Association      8441
# Manufacturers and Traders Trust Company     6105
# Name: count, dtype: int64

# %%
df['AsOfDate']
# Out:
# 0        1970-01-01 00:00:00.020231231
# 1        1970-01-01 00:00:00.020231231
# 2        1970-01-01 00:00:00.020231231
# 3        1970-01-01 00:00:00.020231231
# 4        1970-01-01 00:00:00.020231231
#                       ...
# 213559   1970-01-01 00:00:00.020231231
# 213560   1970-01-01 00:00:00.020231231
# 213561   1970-01-01 00:00:00.020231231
# 213562   1970-01-01 00:00:00.020231231
# 213563   1970-01-01 00:00:00.020231231
# Name: AsOfDate, Length: 213564, dtype: datetime64[ns]

# %%
df['BankCity'].nunique()
# Out:
# 1545

# %%
df['BorrCity'].nunique()
# Out:
# 17593

# %%
df.groupby(['BankName','BankCity']).count()['SBADistrictOffice'].head(5)
# Out:
# BankName                     BankCity
# 121 Financial Credit Union   Jacksonville      3
# 1NB Bank                     CARLYLE           3
# 1st Capital Bank             SALINAS          28
# 1st Colonial Community Bank  COLLINGSWOOD    136
# 1st Community FCU            SAN ANGELO        6
# Name: SBADistrictOffice, dtype: int64

# %%
df.to_csv('Small-Bus.csv')
